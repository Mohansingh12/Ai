# %%
import matplotlib as plt

# %%
import pandas as pd

# %%
db=pd.read_csv("Gold Futures Historical Data.csv")

# %%
db
# Out:
#             Date  Price   Open   High    Low    Vol. Change %
# 0     07-11-1994  383.3  383.8  384.2  383.1  25.39K   -0.36%
# 1     08-11-1994  384.7  384.8  385.3  383.5  14.40K    0.08%
# 2     03-11-1994  384.4  385.0  385.4  384.2  17.75K   -0.29%
# 3     02-11-1994  385.5  384.7  385.7  384.2   9.68K   -0.05%
# 4     01-11-1994  385.7  384.7  386.5  384.3  19.06K    0.21%
# ...          ...    ...    ...    ...    ...     ...      ...
# 4994  09-01-1975  178.3  179.0  179.1  177.0     NaN    0.51%
# 4995  08-01-1975  177.4  176.0  180.0  176.0     NaN    2.31%
# 4996  07-01-1975  173.4  171.0  174.0  168.5     NaN   -0.57%
# 4997  06-01-1975  174.4  172.0  174.5  167.5     NaN   -0.17%
# 4998  03-01-1975  174.7  173.0  175.5  170.5     NaN   -0.23%
#
# [4999 rows x 7 columns]

# %%
db.isnull().any()
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.         True
# Change %    False
# dtype: bool

# %%
db[db['Vol.'].isna()==1]
# Out:
#             Date  Price   Open   High    Low Vol. Change %
# 468   29-12-1992  332.8  332.9  333.1  332.3  NaN   -0.18%
# 469   28-12-1992  333.4  334.2  334.8  333.3  NaN    0.00%
# 470   24-12-1992  333.4  333.3  333.5  333.0  NaN    0.00%
# 471   23-12-1992  333.4  332.8  334.0  332.6  NaN    0.18%
# 472   22-12-1992  332.8  334.1  334.3  332.0  NaN   -0.54%
# ...          ...    ...    ...    ...    ...  ...      ...
# 4994  09-01-1975  178.3  179.0  179.1  177.0  NaN    0.51%
# 4995  08-01-1975  177.4  176.0  180.0  176.0  NaN    2.31%
# 4996  07-01-1975  173.4  171.0  174.0  168.5  NaN   -0.57%
# 4997  06-01-1975  174.4  172.0  174.5  167.5  NaN   -0.17%
# 4998  03-01-1975  174.7  173.0  175.5  170.5  NaN   -0.23%
#
# [4531 rows x 7 columns]

# %%
db = db.drop('Vol.', axis=1)

# %%
db
# Out:
#             Date  Price   Open   High    Low Change %
# 0     07-11-1994  383.3  383.8  384.2  383.1   -0.36%
# 1     08-11-1994  384.7  384.8  385.3  383.5    0.08%
# 2     03-11-1994  384.4  385.0  385.4  384.2   -0.29%
# 3     02-11-1994  385.5  384.7  385.7  384.2   -0.05%
# 4     01-11-1994  385.7  384.7  386.5  384.3    0.21%
# ...          ...    ...    ...    ...    ...      ...
# 4994  09-01-1975  178.3  179.0  179.1  177.0    0.51%
# 4995  08-01-1975  177.4  176.0  180.0  176.0    2.31%
# 4996  07-01-1975  173.4  171.0  174.0  168.5   -0.57%
# 4997  06-01-1975  174.4  172.0  174.5  167.5   -0.17%
# 4998  03-01-1975  174.7  173.0  175.5  170.5   -0.23%
#
# [4999 rows x 6 columns]

# %%
db.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4994    False
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# Length: 4999, dtype: bool

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4999 non-null   object
#  1   Price     4999 non-null   float64
#  2   Open      4999 non-null   float64
#  3   High      4999 non-null   float64
#  4   Low       4999 non-null   float64
#  5   Change %  4999 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 234.5+ KB

# %%
db['Date'] = pd.to_datetime(db['Date'],format="%d-%m-%Y")

# %%
db
# Out:
#            Date  Price   Open   High    Low Change %
# 0    1994-11-07  383.3  383.8  384.2  383.1   -0.36%
# 1    1994-11-08  384.7  384.8  385.3  383.5    0.08%
# 2    1994-11-03  384.4  385.0  385.4  384.2   -0.29%
# 3    1994-11-02  385.5  384.7  385.7  384.2   -0.05%
# 4    1994-11-01  385.7  384.7  386.5  384.3    0.21%
# ...         ...    ...    ...    ...    ...      ...
# 4994 1975-01-09  178.3  179.0  179.1  177.0    0.51%
# 4995 1975-01-08  177.4  176.0  180.0  176.0    2.31%
# 4996 1975-01-07  173.4  171.0  174.0  168.5   -0.57%
# 4997 1975-01-06  174.4  172.0  174.5  167.5   -0.17%
# 4998 1975-01-03  174.7  173.0  175.5  170.5   -0.23%
#
# [4999 rows x 6 columns]

# %%
db['Change %'] = db['Change %'].str.strip('%').astype(float)/100

# %%
db
# Out:
#            Date  Price   Open   High    Low  Change %
# 0    1994-11-07  383.3  383.8  384.2  383.1   -0.0036
# 1    1994-11-08  384.7  384.8  385.3  383.5    0.0008
# 2    1994-11-03  384.4  385.0  385.4  384.2   -0.0029
# 3    1994-11-02  385.5  384.7  385.7  384.2   -0.0005
# 4    1994-11-01  385.7  384.7  386.5  384.3    0.0021
# ...         ...    ...    ...    ...    ...       ...
# 4994 1975-01-09  178.3  179.0  179.1  177.0    0.0051
# 4995 1975-01-08  177.4  176.0  180.0  176.0    0.0231
# 4996 1975-01-07  173.4  171.0  174.0  168.5   -0.0057
# 4997 1975-01-06  174.4  172.0  174.5  167.5   -0.0017
# 4998 1975-01-03  174.7  173.0  175.5  170.5   -0.0023
#
# [4999 rows x 6 columns]

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4999 non-null   datetime64[ns]
#  1   Price     4999 non-null   float64
#  2   Open      4999 non-null   float64
#  3   High      4999 non-null   float64
#  4   Low       4999 non-null   float64
#  5   Change %  4999 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 234.5 KB

# %%
db['year'] = db['Date'].dt.year
db['month'] = db['Date'].dt.month
db['day'] = db['Date'].dt.day
db['weekday'] = db['Date'].dt.weekday
db['is_weekend'] = db['weekday'] >= 5

# %%
db
# Out:
#            Date  Price   Open   High    Low  Change %  year  month  day  \
# 0    1994-11-07  383.3  383.8  384.2  383.1   -0.0036  1994     11    7
# 1    1994-11-08  384.7  384.8  385.3  383.5    0.0008  1994     11    8
# 2    1994-11-03  384.4  385.0  385.4  384.2   -0.0029  1994     11    3
# 3    1994-11-02  385.5  384.7  385.7  384.2   -0.0005  1994     11    2
# 4    1994-11-01  385.7  384.7  386.5  384.3    0.0021  1994     11    1
# ...         ...    ...    ...    ...    ...       ...   ...    ...  ...
# 4994 1975-01-09  178.3  179.0  179.1  177.0    0.0051  1975      1    9
# 4995 1975-01-08  177.4  176.0  180.0  176.0    0.0231  1975      1    8
# 4996 1975-01-07  173.4  171.0  174.0  168.5   -0.0057  1975      1    7
# 4997 1975-01-06  174.4  172.0  174.5  167.5   -0.0017  1975      1    6
# 4998 1975-01-03  174.7  173.0  175.5  170.5   -0.0023  1975      1    3
#
#       weekday  is_weekend
# 0           0       False
# 1           1       False
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(db)

# %%
from sklearn.model_selection import train_test_split

# %%
db
# Out:
#            Date  Price   Open   High    Low  Change %  year  month  day  \
# 0    1994-11-07  383.3  383.8  384.2  383.1   -0.0036  1994     11    7
# 1    1994-11-08  384.7  384.8  385.3  383.5    0.0008  1994     11    8
# 2    1994-11-03  384.4  385.0  385.4  384.2   -0.0029  1994     11    3
# 3    1994-11-02  385.5  384.7  385.7  384.2   -0.0005  1994     11    2
# 4    1994-11-01  385.7  384.7  386.5  384.3    0.0021  1994     11    1
# ...         ...    ...    ...    ...    ...       ...   ...    ...  ...
# 4994 1975-01-09  178.3  179.0  179.1  177.0    0.0051  1975      1    9
# 4995 1975-01-08  177.4  176.0  180.0  176.0    0.0231  1975      1    8
# 4996 1975-01-07  173.4  171.0  174.0  168.5   -0.0057  1975      1    7
# 4997 1975-01-06  174.4  172.0  174.5  167.5   -0.0017  1975      1    6
# 4998 1975-01-03  174.7  173.0  175.5  170.5   -0.0023  1975      1    3
#
#       weekday  is_weekend
# 0           0       False
# 1           1       False
# ...

# %%
X = db[['month','day','year']]
y = db['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)
print(f'R² score: {r2}')
# Out:
# R² score: 0.20523178601284653

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import  mean_absolute_error, mean_squared_error
import numpy as np

print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.9970715378138792
# MAE: 3.4623209999999935
# RMSE: 6.328018881371953

# %%
rf_model.predict([[6,6,2025]])
# Out:
# /home/mohan/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([383.378])
