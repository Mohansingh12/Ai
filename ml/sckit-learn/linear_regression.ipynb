# %%
import pandas as pd

# %%
dp=pd.read_csv("student_habits_performance.csv")

# %%
dp
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
dp.isnull().any()
# Out:
# student_id                       False
# age                              False
# gender                           False
# study_hours_per_day              False
# social_media_hours               False
# netflix_hours                    False
# part_time_job                    False
# attendance_percentage            False
# sleep_hours                      False
# diet_quality                     False
# exercise_frequency               False
# parental_education_level          True
# internet_quality                 False
# mental_health_rating             False
# extracurricular_participation    False
# exam_score                       False
# dtype: bool

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
dp.ffill()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
dp.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()

# %%
gender_encoded = encoder.fit_transform(dp[['gender']])

# %%
gender_df = pd.DataFrame(gender_encoded, columns=encoder.get_feature_names_out([['gender']]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 gender_df = pd.DataFrame(gender_encoded, columns=encoder.get_feature_names_out([['gender']]))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1208, in OneHotEncoder.get_feature_names_out(self, input_features)
#    1188 """Get output feature names for transformation.
#    1189
#    1190 Parameters
#    (...)
#    1205     Transformed feature names.
#    1206 """
#    1207 check_is_fitted(self)
# -> 1208 input_features = _check_feature_names_in(self, input_features)
#    1209 cats = [
#    1210     self._compute_transformed_categories(i)
#    1211     for i, _ in enumerate(self.categories_)
#    1212 ]
#    1214 name_combiner = self._check_get_feature_name_combiner()
#
# ...

# %%
dp = dp.join(gender_df)
